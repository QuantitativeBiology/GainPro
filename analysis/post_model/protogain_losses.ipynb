# %%
import pandas as pd
from pathlib import Path

from plots import plot_loss

# %% [markdown]
# # Plot functions

# %%
protogain_dir = Path("../../experiments/benchmark/PXD030304_no_control_multi_peptide_50pct_tissue/official/protogain/holdout/benchmark_2026-05-08_16:10:13/protogain/miss_10/run_001_seed_42_2026-05-08_16:10:14")

# %%
training_metrics = pd.read_csv(protogain_dir / "training/metrics/train.csv")

# %%
plot_loss(name_loss="Discriminator Entropy", train_loss=training_metrics["generator_entropy"])
plot_loss(name_loss="Discriminator Loss", train_loss=training_metrics["discriminator_loss"])
plot_loss(name_loss="Generator RMSE", train_loss=training_metrics["generator_rmse"])
